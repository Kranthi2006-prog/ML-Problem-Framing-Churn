# %%
1. Import libraries
2. Load customer-churn-training.csv
3. Inspect dataset
4. Check missing values
5. Check duplicates
6. Examine churn distribution
7. Analyze features
8. Create non-ML baseline
9. Calculate baseline metrics
10. Explain baseline limitations
